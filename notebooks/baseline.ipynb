# %% [markdown]
# # Baseline: Linear Regression models
#
# We will use linear regression models as baseline for this problem. These will include Ridge, Lasso and ElasticNet.

# %%
# Imports
import pandas as pd
import numpy as np 
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import Ridge, Lasso, ElasticNet
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %%
# Load datasets 
train_df = pd.read_csv("/Users/mateopozoruiz/Projects/Housing-Pricing-End-to-End-ML/data/processed/feature_engineered_train_data.csv")
test_df = pd.read_csv("/Users/mateopozoruiz/Projects/Housing-Pricing-End-to-End-ML/data/processed/feature_engineered_test_data.csv")

# %%
"""
# Drop high VIF features and low MI features excluding date-related features
high_vif_features = ['Total School Age Population', 'median_list_price']
low_mi_features = ['bus', 'off_market_in_two_weeks', 'mall']

excluded_features = high_vif_features + low_mi_features

train_df.drop(columns=excluded_features, inplace=True)
test_df.drop(columns=excluded_features, inplace=True)
"""
# Out:
# "\n# Drop high VIF features and low MI features excluding date-related features\nhigh_vif_features = ['Total School Age Population', 'median_list_price']\nlow_mi_features = ['bus', 'off_market_in_two_weeks', 'mall']\n\nexcluded_features = high_vif_features + low_mi_features\n\ntrain_df.drop(columns=excluded_features, inplace=True)\ntest_df.drop(columns=excluded_features, inplace=True)\n"

# %%
# Define features and target variable
target = 'price'
X_train = train_df.drop(columns=[target])
y_train = train_df[target]

X_test = test_df.drop(columns=[target])
y_test = test_df[target]

# %%
# Data scaling
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %% [markdown]
# ## Train and Evaluate Models

# %% [markdown]
# ### Ridge Regression

# %%
ridge = Ridge(alpha=1.0)
ridge.fit(X_train_scaled, y_train)
y_pred_ridge = ridge.predict(X_test_scaled)

print("Ridge Regression Performance:")
print("MAE:", mean_absolute_error(y_test, y_pred_ridge))
print("RMSE:", np.sqrt(mean_squared_error(y_test, y_pred_ridge)))
print("R²:", r2_score(y_test, y_pred_ridge))
# Out:
# Ridge Regression Performance:
# MAE: 54057.962934115916
# RMSE: 121373.00945850201
# R²: 0.8861575399128494
# /Users/mateopozoruiz/Projects/Housing-Pricing-End-to-End-ML/.venv/lib/python3.10/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/mateopozoruiz/Projects/Housing-Pricing-End-to-End-ML/.venv/lib/python3.10/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/mateopozoruiz/Projects/Housing-Pricing-End-to-End-ML/.venv/lib/python3.10/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/mateopozoruiz/Projects/Housing-Pricing-End-to-End-ML/.venv/lib/python3.10/site-packages/sklearn/linear_model/_base.py:280: RuntimeWarning: divide by zero encountered in matmul
#   return X @ coef_ + self.intercept_
# ...

# %% [markdown]
# ### Lasso Regression

# %%
lasso = Lasso(alpha=0.25)
lasso.fit(X_train_scaled, y_train)
y_pred_lasso = lasso.predict(X_test_scaled)

print("\nLasso Regression Performance:")
print("MAE:", mean_absolute_error(y_test, y_pred_lasso))
print("RMSE:", np.sqrt(mean_squared_error(y_test, y_pred_lasso)))
print("R²:", r2_score(y_test, y_pred_lasso))
# Out:
# Lasso Regression Performance:
# MAE: 54442.3774332873
# RMSE: 121676.80004144394
# R²: 0.8855869427295857
# /Users/mateopozoruiz/Projects/Housing-Pricing-End-to-End-ML/.venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.093e+15, tolerance: 5.209e+12
#   model = cd_fast.enet_coordinate_descent(
# /Users/mateopozoruiz/Projects/Housing-Pricing-End-to-End-ML/.venv/lib/python3.10/site-packages/sklearn/linear_model/_base.py:280: RuntimeWarning: divide by zero encountered in matmul
#   return X @ coef_ + self.intercept_
# /Users/mateopozoruiz/Projects/Housing-Pricing-End-to-End-ML/.venv/lib/python3.10/site-packages/sklearn/linear_model/_base.py:280: RuntimeWarning: overflow encountered in matmul
#   return X @ coef_ + self.intercept_
# ...

# %% [markdown]
# ### ElasticNet

# %%
elasticnet = ElasticNet(alpha=0.1, l1_ratio=0.5)
elasticnet.fit(X_train_scaled, y_train)
y_pred_elasticnet = elasticnet.predict(X_test_scaled)

print("\nElasticNet Regression Performance:")
print("MAE:", mean_absolute_error(y_test, y_pred_elasticnet))
print("RMSE:", np.sqrt(mean_squared_error(y_test, y_pred_elasticnet)))
print("R²:", r2_score(y_test, y_pred_elasticnet))
# Out:
# ElasticNet Regression Performance:
# MAE: 54198.64460317352
# RMSE: 122236.80913582923
# R²: 0.8845313627527687
# /Users/mateopozoruiz/Projects/Housing-Pricing-End-to-End-ML/.venv/lib/python3.10/site-packages/sklearn/linear_model/_base.py:280: RuntimeWarning: divide by zero encountered in matmul
#   return X @ coef_ + self.intercept_
# /Users/mateopozoruiz/Projects/Housing-Pricing-End-to-End-ML/.venv/lib/python3.10/site-packages/sklearn/linear_model/_base.py:280: RuntimeWarning: overflow encountered in matmul
#   return X @ coef_ + self.intercept_
# /Users/mateopozoruiz/Projects/Housing-Pricing-End-to-End-ML/.venv/lib/python3.10/site-packages/sklearn/linear_model/_base.py:280: RuntimeWarning: invalid value encountered in matmul
#   return X @ coef_ + self.intercept_
